# %% [markdown]
# # Homework solution TensorFlow: Fashion MNIST
#
# https://www.kaggle.com/zalando-research/fashionmnist

# %% [markdown]
# ## Loading the dataset

# %%
import tensorflow
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import fashion_mnist

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
i = np.random.randint(0, len(X_train))
plt.imshow(X_train[i], cmap = 'gray')
plt.title('Class ' + str(y_train[i]))
# Out:
# Text(0.5, 1.0, 'Class 2')

# %%
X_train = X_train.reshape(60000, 28 * 28)
X_test = X_test.reshape(10000, 28 * 28)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %% [markdown]
# ## Neural network (training)

# %%
network = Sequential()
network.add(Dense(input_shape = (784,), units = 397, activation = 'relu'))
network.add(Dense(units = 397, activation = 'relu'))
network.add(Dense(units = 10, activation = 'softmax'))

# %%
network.compile(loss = 'sparse_categorical_crossentropy', 
                      optimizer = 'adam', 
                      metrics = ['accuracy'])

# %%
history = network.fit(X_train, y_train, batch_size = 128, epochs = 100)
# Out:
# Epoch 1/100
# 469/469 [==============================] - 19s 37ms/step - loss: 4.1067 - accuracy: 0.7641
# Epoch 2/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.6474 - accuracy: 0.8149
# Epoch 3/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.5042 - accuracy: 0.8369
# Epoch 4/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.4491 - accuracy: 0.8474
# Epoch 5/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.4397 - accuracy: 0.8501
# Epoch 6/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3993 - accuracy: 0.8600
# Epoch 7/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3873 - accuracy: 0.8631
# Epoch 8/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3814 - accuracy: 0.8664
# Epoch 9/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.3614 - accuracy: 0.8706
# Epoch 10/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.3582 - accuracy: 0.8722
# Epoch 11/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.3432 - accuracy: 0.8772
# Epoch 12/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.3474 - accuracy: 0.8743
# Epoch 13/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.3255 - accuracy: 0.8823
# Epoch 14/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.3213 - accuracy: 0.8840
# Epoch 15/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.3088 - accuracy: 0.8854
# Epoch 16/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3011 - accuracy: 0.8903
# Epoch 17/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2951 - accuracy: 0.8905
# Epoch 18/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2971 - accuracy: 0.8897
# Epoch 19/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2801 - accuracy: 0.8958
# Epoch 20/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2761 - accuracy: 0.8973
# Epoch 21/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2816 - accuracy: 0.8966
# Epoch 22/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2823 - accuracy: 0.8963
# Epoch 23/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2758 - accuracy: 0.8990
# Epoch 24/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2687 - accuracy: 0.9001
# Epoch 25/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2648 - accuracy: 0.9010
# Epoch 26/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2731 - accuracy: 0.9003
# Epoch 27/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2683 - accuracy: 0.9029
# Epoch 28/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2637 - accuracy: 0.9028
# Epoch 29/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2571 - accuracy: 0.9052
# Epoch 30/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2581 - accuracy: 0.9043
# Epoch 31/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2487 - accuracy: 0.9079
# Epoch 32/100
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2495 - accuracy: 0.9082
# Epoch 33/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2446 - accuracy: 0.9091
# Epoch 34/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2378 - accuracy: 0.9115
# Epoch 35/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2438 - accuracy: 0.9110
# Epoch 36/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2382 - accuracy: 0.9123
# Epoch 37/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2352 - accuracy: 0.9140
# Epoch 38/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2416 - accuracy: 0.9107
# Epoch 39/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2440 - accuracy: 0.9125
# Epoch 40/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2243 - accuracy: 0.9161
# Epoch 41/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2250 - accuracy: 0.9157
# Epoch 42/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2282 - accuracy: 0.9162
# Epoch 43/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2188 - accuracy: 0.9179
# Epoch 44/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2297 - accuracy: 0.9150
# Epoch 45/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2215 - accuracy: 0.9185
# Epoch 46/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2183 - accuracy: 0.9190
# Epoch 47/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2146 - accuracy: 0.9204
# Epoch 48/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2129 - accuracy: 0.9203
# Epoch 49/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2095 - accuracy: 0.9221
# Epoch 50/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2124 - accuracy: 0.9226
# Epoch 51/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2110 - accuracy: 0.9226
# Epoch 52/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2200 - accuracy: 0.9202
# Epoch 53/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2049 - accuracy: 0.9243
# Epoch 54/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2155 - accuracy: 0.9229
# Epoch 55/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2172 - accuracy: 0.9211
# Epoch 56/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1973 - accuracy: 0.9259
# Epoch 57/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2076 - accuracy: 0.9232
# Epoch 58/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2088 - accuracy: 0.9233
# Epoch 59/100
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1963 - accuracy: 0.9275
# Epoch 60/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1961 - accuracy: 0.9273
# Epoch 61/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2036 - accuracy: 0.9256
# Epoch 62/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1894 - accuracy: 0.9293
# Epoch 63/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2046 - accuracy: 0.9251
# Epoch 64/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1967 - accuracy: 0.9281
# Epoch 65/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1926 - accuracy: 0.9285
# Epoch 66/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1961 - accuracy: 0.9279
# Epoch 67/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2020 - accuracy: 0.9266
# Epoch 68/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1802 - accuracy: 0.9326
# Epoch 69/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1968 - accuracy: 0.9273
# Epoch 70/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1919 - accuracy: 0.9295
# Epoch 71/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1884 - accuracy: 0.9301
# Epoch 72/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2004 - accuracy: 0.9279
# Epoch 73/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1912 - accuracy: 0.9310
# Epoch 74/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1878 - accuracy: 0.9307
# Epoch 75/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1791 - accuracy: 0.9335
# Epoch 76/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1829 - accuracy: 0.9327
# Epoch 77/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2016 - accuracy: 0.9278
# Epoch 78/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1901 - accuracy: 0.9295
# Epoch 79/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1825 - accuracy: 0.9324
# Epoch 80/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1799 - accuracy: 0.9323
# Epoch 81/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1802 - accuracy: 0.9326
# Epoch 82/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1862 - accuracy: 0.9327
# Epoch 83/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1805 - accuracy: 0.9339
# Epoch 84/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1809 - accuracy: 0.9325
# Epoch 85/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1836 - accuracy: 0.9326
# Epoch 86/100
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1850 - accuracy: 0.9324
# Epoch 87/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1865 - accuracy: 0.9326
# Epoch 88/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1841 - accuracy: 0.9321
# Epoch 89/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1786 - accuracy: 0.9342
# Epoch 90/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1746 - accuracy: 0.9364
# Epoch 91/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1768 - accuracy: 0.9350
# Epoch 92/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1714 - accuracy: 0.9371
# Epoch 93/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1683 - accuracy: 0.9378
# Epoch 94/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1715 - accuracy: 0.9356
# Epoch 95/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1864 - accuracy: 0.9326
# Epoch 96/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1671 - accuracy: 0.9385
# Epoch 97/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1778 - accuracy: 0.9346
# Epoch 98/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1794 - accuracy: 0.9351
# Epoch 99/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1708 - accuracy: 0.9369
# Epoch 100/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1642 - accuracy: 0.9383

# %% [markdown]
# ## Neural network (evaluation)

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
plt.plot(history.history['loss'])

# %%
plt.plot(history.history['accuracy'])

# %%
accuracy_test = network.evaluate(X_test, y_test)
print(accuracy_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6189 - accuracy: 0.8763

# %%
plt.imshow(X_test[0].reshape(28, 28), cmap = 'gray')
plt.title('Class ' + str(y_test[0]))
# Out:
# Text(0.5, 1.0, 'Class 9')
